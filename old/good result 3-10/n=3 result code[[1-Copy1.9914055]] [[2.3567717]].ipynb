# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
n=3;
def appen2(x1,x2,y):
    trainingdata.append([x1,x2])
    traininglabel.append([y])
    
def appen(x1,x2,x3):
    
                
    S= max(x1+x2+x3,1.0);
                                
                                
    appen2(x2,x3,S)
    appen2(x1,x3,S)
    appen2(x1,x2,S)

def readdata():
    devided=30
    for i1 in range(devided+1):
        for i2 in range(i1+1):
            for i3 in range(i2+1):
                appen(i1/devided,i2/devided,i3/devided);
                            

trainingdata=[]
traininglabel=[]
S=1.0
readdata();

# %%
trainingdata=np.array(trainingdata)
traininglabel=np.array(traininglabel)

# %%
#print(trainingdata)

import tensorflow as tf
#导入TensorFlow工具包并简称为tf
 
from numpy.random import RandomState
#导入numpy工具包，生成模拟数据集


w1 = tf.Variable(tf.truncated_normal([2,100],stddev=0.1))
w2 = tf.Variable(tf.truncated_normal([100,100],stddev=0.1))
w3 = tf.Variable(tf.truncated_normal([100,100],stddev=0.1))
w4 = tf.Variable(tf.truncated_normal([100,1],stddev=0.1))

biases1 = tf.Variable(tf.zeros([1,100])+0.01)
biases2 = tf.Variable(tf.zeros([1,100])+0.01)
biases3 = tf.Variable(tf.zeros([1,100])+0.01)
biases4 = tf.Variable(tf.zeros([1,1])+0.01)


lr = tf.Variable(0.01,dtype=tf.float32)
lr2 = tf.Variable(0.1,dtype=tf.float32)
#分别定义一二层和二三层之间的网络参数，标准差为1，随机产生的数保持一致

with tf.name_scope('input'):
    x = tf.placeholder(tf.float32,shape=(None,2),name='x-input')
    y_ = tf.placeholder(tf.float32,shape=(None,1),name='y-input')
#输入为两个维度，即两个特征，输出为一个标签,声明数据类型float32，None即一个batch大小
#y_是真实的标签

x1 = tf.nn.relu(tf.matmul(x,w1)+biases1)
x2 = tf.nn.relu(tf.matmul(x1,w2)+biases2)
x3 =  tf.nn.relu(tf.matmul(x2,w3)+biases3)
y =  tf.nn.relu(tf.matmul(x3,w4)+biases4)
#定义神经网络前向传播过程

print(x1)
X=trainingdata;
Y=traininglabel;


batch_size = n
dataset_size = len(X)
#定义训练数据batch的大小

loss=tf.where(tf.greater(tf.reduce_sum(y),tf.reduce_sum(y_)*2.0/n),  
                             tf.where(
                                 tf.greater(tf.reduce_sum(y),tf.reduce_sum(y_)*2.334/n),
                                tf.square(tf.reduce_sum(y)-tf.reduce_sum(y_)*2.334/n)/9,
                                 (0.0*tf.reduce_sum(y_))
                                     )  , 
                             tf.square(tf.reduce_sum(y_)*2.0/n-tf.reduce_sum(y))/9
                            )

train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)

#loss3=tf.reduce_mean(tf.square(tf.reduce_sum(y)-tf.reduce_sum(y_)*6.25/7))
#loss=tf.reduce_mean(tf.where(tf.greater(y_up,y),  
#                             tf.where(tf.greater(y,y_low),tf.square(y-y),tf.square(y-y_low))  , 
#                             tf.square(y-y_up))
#                   )
#loss1 = tf.reduce_mean(tf.square(y-(y_up+y_low)/2))

#loss2 = tf.reduce_max(tf.square(y-y_up)+tf.square(y-y_low))

#loss = tf.reduce_mean(tf.square(y-y_))
#loss1 = tf.reduce_max(tf.square(y-y_))
#cross_entropy = tf.reduce_max(tf.square(y-y_))
#cross_entropy = tf.reduce_mean(tf.where(tf.greater(y_,y),  tf.square(y-y_), tf.square(y-y)))
#cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_,logits=y))

#train_step=tf.train.AdamOptimizer(lr).minimize(loss)
#train_step2=tf.train.AdamOptimizer(lr).minimize(loss2)
#train_step=tf.train.Optimizer(0.01).minimize(cross_entropy)
#定义损失函数和反向传播算法
# Out:
# Tensor("Relu:0", shape=(?, 100), dtype=float32)

# %%
if 'session' in locals() and session is not None:
    print('Close interactive session')
    session.close()

# %%
def run_graph(x1,x2):
    ans = sess.run(y,feed_dict={x:[[x1,x2]]})
    return ans



def judgement(x1,x2,x3):
    S= max(x1+x2+x3,1.0);
                                    
    y1 = run_graph(x2,x3)
    y2 = run_graph(x1,x3)
    y3 = run_graph(x1,x2)

                                
    sum_all=(y1+y2+y3)/S;
    if(sum_all>=2.35):
        print(x1,x2,x3,sum_all);
    if(sum_all<=1.98):
        print(x1,x2,x3,sum_all);
    return sum_all;


saver = tf.train.Saver()
#创建会话来运行TensorFlow程序
with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    writer=tf.summary.FileWriter('logs/',sess.graph)
 
 

    save_path = saver.restore(sess, "savenetwork3[[1.9914055]] [[2.3567717]]/3.ckpt")
    #save_path = saver.restore(sess, "n=4 good result network and value/4.ckpt")

    
    STEPS = 0
    #设置训练的轮数
    for i in range(STEPS):
        start = (i * n) % dataset_size
        end = min(start+batch_size,dataset_size)

	#每次选取batch_size个样本进行训练
        #total_cross_entropy = sess.run(cross_entropy,feed_dict={x:X,y_:Y})

        sess.run(train_step,feed_dict={x:X[start:end],y_:Y[start:end]})
        #sess.run(train_step,feed_dict={x:X[start:end],y_up:Y_up[start:end],y_low:Y_low[start:end]})
	#通过选取的样本训练神经网络并更新参数
    
    
        print(sess.run(x,feed_dict={x:X[start:end],y_:Y[start:end]}))
        print(sess.run(x1,feed_dict={x:X[start:end],y_:Y[start:end]}))
        
        if i%1000 == 0:
            sess.run(tf.assign(lr,0.01*(0.95**(i/1000))))
            sess.run(tf.assign(lr2,0.1*(0.95**(i/1000))))
            loss_value=0;
            if i%10000 == 0:
                for j1 in range(0,(int)(len(X)/10),n):
                    j2=j1+n
                    loss_value += sess.run(loss,feed_dict={x:X[j1:j2],y_:Y[j1:j2]})
                print("After %d training step(s),loss on data is %g" % (i,loss_value))
        if i%100 == 101:
            if((i/100)%3==0):
                j=0;
                train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
            elif((i/100)%3==1):
                j=0;
                train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
            else:
                j=0;
                train_step=tf.train.AdamOptimizer(lr).minimize(loss)
    
    # 必须要指定文件夹，保存到ckpt文件
    #save_path = saver.save(sess, "savenetwork_good_result_3/3.ckpt")

    # 必须要指定文件夹，保存到ckpt文件
    #save_path = saver.save(sess, "savenetwork4/4.ckpt")

    
    start = (0 * n) % dataset_size
    end = min(start+batch_size,dataset_size)

	#每次选取batch_size个样本进行训练
        #total_cross_entropy = sess.run(cross_entropy,feed_dict={x:X,y_:Y})
    print(X[start:end])
    print(sess.run(x1,feed_dict={x:X[start:end],y_:Y[start:end]}))
    
    print(sess.run(y,feed_dict={x:X[start:end],y_:Y[start:end]}))
    #打印出训练之后神经网络参数的值
    mi=10000000;
    ma=0;
    devided=10
    for i1 in range(devided+1):
        for i2 in range(i1+1):
            for i3 in range(i2+1):
                sum_all=judgement(i1/devided,i2/devided,i3/devided);
                mi= min(sum_all,mi);
                ma= max(sum_all,ma);

    print(mi, ma)
# Out:
# INFO:tensorflow:Restoring parameters from savenetwork3[[1.9914055]] [[2.3567717]]/3.ckpt
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#
# InternalError: Blas GEMM launch failed : a.shape=(3, 2), b.shape=(2, 100), m=3, n=100, k=2
# 	 [[{{node MatMul}} = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_input/x-input_0_0/_21, Variable/read)]]
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-6-cedf4bd08164> in <module>
#      86         #total_cross_entropy = sess.run(cross_entropy,feed_dict={x:X,y_:Y})
#      87     print(X[start:end])
# ---> 88     print(sess.run(x1,feed_dict={x:X[start:end],y_:Y[start:end]}))
#      89
#      90     print(sess.run(y,feed_dict={x:X[start:end],y_:Y[start:end]}))
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1306           self._config.experimental.client_handles_error_formatting):
#    1307         message = error_interpolation.interpolate(message, self._graph)
# -> 1308       raise type(e)(node_def, op, message)
#    1309
#    1310   def _extend_graph(self):
#
# InternalError: Blas GEMM launch failed : a.shape=(3, 2), b.shape=(2, 100), m=3, n=100, k=2
# 	 [[{{node MatMul}} = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_input/x-input_0_0/_21, Variable/read)]]
#
# Caused by op 'MatMul', defined at:
#   File "D:\ComputerSoftwares\Anaconda\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "D:\ComputerSoftwares\Anaconda\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ComputerSoftwares\Anaconda\lib\asyncio\base_events.py", line 427, in run_forever
#     self._run_once()
#   File "D:\ComputerSoftwares\Anaconda\lib\asyncio\base_events.py", line 1440, in _run_once
#     handle._run()
#   File "D:\ComputerSoftwares\Anaconda\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2843, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2869, in _run_cell
#     return runner(coro)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3044, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3209, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-49fed62f4ced>", line 31, in <module>
#     x1 = tf.nn.relu(tf.matmul(x,w1)+biases1)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\ops\math_ops.py", line 2053, in matmul
#     a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 4560, in mat_mul
#     name=name)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\util\deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py", line 3272, in create_op
#     op_def=op_def)
#   File "D:\ComputerSoftwares\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py", line 1768, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InternalError (see above for traceback): Blas GEMM launch failed : a.shape=(3, 2), b.shape=(2, 100), m=3, n=100, k=2
# 	 [[{{node MatMul}} = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_input/x-input_0_0/_21, Variable/read)]]
