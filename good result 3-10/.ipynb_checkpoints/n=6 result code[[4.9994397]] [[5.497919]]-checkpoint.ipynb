# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
n=6;
def appen2(x1,x2,x3,x4,x5,y):
    trainingdata.append([x1,x2,x3,x4,x5])
    traininglabel.append([y])
    
def appen(x1,x2,x3,x4,x5,x6):
    
                
    S= max(x1+x2+x3+x4+x5+x6,1.0);
                                
                                
    appen2(x2,x3,x4,x5,x6,S)
    appen2(x1,x3,x4,x5,x6,S)
    appen2(x1,x2,x4,x5,x6,S)
    appen2(x1,x2,x3,x5,x6,S)
    appen2(x1,x2,x3,x4,x6,S)
    appen2(x1,x2,x3,x4,x5,S)
    
def readdata():
    devided=16
    for i1 in range(devided+1):
        for i2 in range(i1+1):
            for i3 in range(i2+1):
                for i4 in range(i3+1):
                    for i5 in range(i4+1):
                        for i6 in range(i5+1):
                            appen(i1/devided,i2/devided,i3/devided,i4/devided,i5/devided,i6/devided);
                            

trainingdata=[]
traininglabel=[]
S=1.0
readdata();

# %%
trainingdata=np.array(trainingdata)
traininglabel=np.array(traininglabel)

# %%
#print(trainingdata)

import tensorflow as tf
#导入TensorFlow工具包并简称为tf
 
from numpy.random import RandomState
#导入numpy工具包，生成模拟数据集


w1 = tf.Variable(tf.truncated_normal([5,100],stddev=0.1))
w2 = tf.Variable(tf.truncated_normal([100,100],stddev=0.1))
w3 = tf.Variable(tf.truncated_normal([100,100],stddev=0.1))
w4 = tf.Variable(tf.truncated_normal([100,1],stddev=0.1))

biases1 = tf.Variable(tf.zeros([1,100])+0.01)
biases2 = tf.Variable(tf.zeros([1,100])+0.01)
biases3 = tf.Variable(tf.zeros([1,100])+0.01)
biases4 = tf.Variable(tf.zeros([1,1])+0.01)


lr = tf.Variable(0.01,dtype=tf.float32)
lr2 = tf.Variable(0.1,dtype=tf.float32)
#分别定义一二层和二三层之间的网络参数，标准差为1，随机产生的数保持一致

with tf.name_scope('input'):
    x = tf.placeholder(tf.float32,shape=(None,5),name='x-input')
    y_ = tf.placeholder(tf.float32,shape=(None,1),name='y-input')
#输入为两个维度，即两个特征，输出为一个标签,声明数据类型float32，None即一个batch大小
#y_是真实的标签

x1 = tf.nn.relu(tf.matmul(x,w1)+biases1)
x2 = tf.nn.relu(tf.matmul(x1,w2)+biases2)
x3 =  tf.nn.relu(tf.matmul(x2,w3)+biases3)
y =  tf.nn.relu(tf.matmul(x3,w4)+biases4)
#定义神经网络前向传播过程


X=trainingdata;
Y=traininglabel;


batch_size = n
dataset_size = len(X)
#定义训练数据batch的大小

loss=tf.where(tf.greater(tf.reduce_sum(y),tf.reduce_sum(y_)*5.00/n),  
                             tf.where(
                                 tf.greater(tf.reduce_sum(y),tf.reduce_sum(y_)*5.48/n),
                                tf.square(tf.reduce_sum(y)-tf.reduce_sum(y_)*5.48/n)/9,
                                 (0.0*tf.reduce_sum(y_))
                                     )  , 
                             tf.square(tf.reduce_sum(y_)*5.00/n-tf.reduce_sum(y))/9
                            )

train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)

#loss3=tf.reduce_mean(tf.square(tf.reduce_sum(y)-tf.reduce_sum(y_)*6.25/7))
#loss=tf.reduce_mean(tf.where(tf.greater(y_up,y),  
#                             tf.where(tf.greater(y,y_low),tf.square(y-y),tf.square(y-y_low))  , 
#                             tf.square(y-y_up))
#                   )
#loss1 = tf.reduce_mean(tf.square(y-(y_up+y_low)/2))

#loss2 = tf.reduce_max(tf.square(y-y_up)+tf.square(y-y_low))

#loss = tf.reduce_mean(tf.square(y-y_))
#loss1 = tf.reduce_max(tf.square(y-y_))
#cross_entropy = tf.reduce_max(tf.square(y-y_))
#cross_entropy = tf.reduce_mean(tf.where(tf.greater(y_,y),  tf.square(y-y_), tf.square(y-y)))
#cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_,logits=y))

#train_step=tf.train.AdamOptimizer(lr).minimize(loss)
#train_step2=tf.train.AdamOptimizer(lr).minimize(loss2)
#train_step=tf.train.Optimizer(0.01).minimize(cross_entropy)
#定义损失函数和反向传播算法
# Out:
# d:\miniconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def run_graph(x1,x2,x3,x4,x5):
    ans = sess.run(y,feed_dict={x:[[x1,x2,x3,x4,x5]]})
    return ans



def judgement(x1,x2,x3,x4,x5,x6):
    S= max(x1+x2+x3+x4+x5+x6,1.0);
                                    
    y1 = run_graph(x2,x3,x4,x5,x6)
    y2 = run_graph(x1,x3,x4,x5,x6)
    y3 = run_graph(x1,x2,x4,x5,x6)
    y4 = run_graph(x1,x2,x3,x5,x6)
    y5 = run_graph(x1,x2,x3,x4,x6)
    y6 = run_graph(x1,x2,x3,x4,x5)
                                
    sum_all=(y1+y2+y3+y4+y5+y6)/S;
    if(sum_all>=5.7):
        print(x1,x2,x3,x4,x5,x6,sum_all);
    if(sum_all<=4.9):
        print(x1,x2,x3,x4,x5,x6,sum_all);
    return sum_all;
    
saver = tf.train.Saver()
#创建会话来运行TensorFlow程序
with tf.Session() as sess:
    init_op = tf.global_variables_initializer()
    sess.run(init_op)
    writer=tf.summary.FileWriter('logs/',sess.graph)
 
 

    save_path = saver.restore(sess, "savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt")
    #save_path = saver.restore(sess, "n=4 good result network and value/4.ckpt")

    
    STEPS = 0
    #设置训练的轮数
    for i in range(STEPS):
        start = (i * n) % dataset_size
        end = min(start+batch_size,dataset_size)

	#每次选取batch_size个样本进行训练
        #total_cross_entropy = sess.run(cross_entropy,feed_dict={x:X,y_:Y})
        sess.run(train_step,feed_dict={x:X[start:end],y_:Y[start:end]})
        #sess.run(train_step,feed_dict={x:X[start:end],y_up:Y_up[start:end],y_low:Y_low[start:end]})
	#通过选取的样本训练神经网络并更新参数

    
        if i%1000 == 0:
            sess.run(tf.assign(lr,0.01*(0.95**(i/1000))))
            sess.run(tf.assign(lr2,0.1*(0.95**(i/1000))))
            loss_value=0;
            if i%10000 == 0:
                for j1 in range(0,(int)(len(X)/10),n):
                    j2=j1+n
                    loss_value += sess.run(loss,feed_dict={x:X[j1:j2],y_:Y[j1:j2]})
                print("After %d training step(s),loss on data is %g" % (i,loss_value))
        if i%100 == 101:
            if((i/100)%3==0):
                j=0;
                train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
            elif((i/100)%3==1):
                j=0;
                train_step=tf.train.GradientDescentOptimizer(lr2).minimize(loss)
            else:
                j=0;
                train_step=tf.train.AdamOptimizer(lr).minimize(loss)
    
    # 必须要指定文件夹，保存到ckpt文件
    #save_path = saver.save(sess, "savenetwork_good_result_6/6.ckpt")

    # 必须要指定文件夹，保存到ckpt文件
    #save_path = saver.save(sess, "savenetwork4/4.ckpt")

    #打印出训练之后神经网络参数的值
    mi=10000000;
    ma=0;
    devided=10
    for i1 in range(devided+1):
        for i2 in range(i1+1):
            for i3 in range(i2+1):
                for i4 in range(i3+1):
                    for i5 in range(i4+1):
                        for i6 in range(i5+1):
                            sum_all=judgement(i1/devided,i2/devided,i3/devided,i4/devided,i5/devided,i6/devided);
                            mi= min(sum_all,mi);
                            ma= max(sum_all,ma);

    print(mi, ma)
# Out:
# INFO:tensorflow:Restoring parameters from savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#
# d:\miniconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt
# 	 [[Node: save/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-768541aac802> in <module>()
#      33
#      34
# ---> 35     save_path = saver.restore(sess, "savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt")
#      36     #save_path = saver.restore(sess, "n=4 good result network and value/4.ckpt")
#      37
#
# d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1773     else:
#    1774       sess.run(self.saver_def.restore_op_name,
# -> 1775                {self.saver_def.filename_tensor_name: save_path})
#    1776
#    1777   @staticmethod
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# d:\miniconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt
# 	 [[Node: save/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save/RestoreV2', defined at:
#   File "d:\miniconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "d:\miniconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "d:\miniconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "d:\miniconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "d:\miniconda3\lib\site-packages\ipykernel\kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "d:\miniconda3\lib\site-packages\tornado\platform\asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "d:\miniconda3\lib\asyncio\base_events.py", line 421, in run_forever
#     self._run_once()
#   File "d:\miniconda3\lib\asyncio\base_events.py", line 1431, in _run_once
#     handle._run()
#   File "d:\miniconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "d:\miniconda3\lib\site-packages\tornado\ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "d:\miniconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "d:\miniconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "d:\miniconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "d:\miniconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "d:\miniconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "d:\miniconda3\lib\site-packages\tornado\stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "d:\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "d:\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "d:\miniconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "d:\miniconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "d:\miniconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "d:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "d:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "d:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "d:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-768541aac802>", line 26, in <module>
#     saver = tf.train.Saver()
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1311, in __init__
#     self.build()
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1320, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1357, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 809, in _build_internal
#     restore_sequentially, reshape)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 448, in _AddRestoreOps
#     restore_sequentially)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\training\saver.py", line 860, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1541, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3290, in create_op
#     op_def=op_def)
#   File "d:\miniconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1654, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Unsuccessful TensorSliceReader constructor: Failed to find any matching files for savenetwork6[[4.9994893]] [[5.50043]]/6.ckpt
# 	 [[Node: save/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]
